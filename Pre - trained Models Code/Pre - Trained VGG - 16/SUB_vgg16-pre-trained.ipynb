# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path)

    train_datagen = ImageDataGenerator(validation_split=0.3)

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    validation_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation', shuffle=False)

    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    print(noOfClasses,class_names, train_generator, validation_generator)
    
    return noOfClasses,class_names, train_generator, validation_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
def initiateModel(noOfClasses):
    modelInput = tf.keras.applications.VGG16(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
def initiateParams(className, model, lr):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + 'VGG16.h5', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
# def modelFit(model, annealer, checkpoint, epochs=20, batchSize = 256):

#     history = model.fit(
#       train_generator,
#       validation_data=validation_generator,
#       epochs=epochs,
#       batch_size=batchSize,
#       callbacks=[annealer, checkpoint],
#       steps_per_epoch=len(train_generator),
#       validation_steps=len(validation_generator)
#     )
    
#     return history

# # def modelFit(model, annealer, checkpoint, epochs=20, batchSize = 256):

# #     history = model.fit(
# #       train_generator,
# #       validation_data=validation_generator,
# #       epochs=epochs,
# #       batch_size=batchSize,
# #       callbacks=[annealer, checkpoint],
# #       steps_per_epoch=len(train_generator),
# #       validation_steps=len(validation_generator)
# #     )
    
# #     return history

# def modelFit(model, annealer, checkpoint, epochs = 20, batchSize = 256, validation_steps = 32):
#     # Assuming you have train_generator and validation_generator defined
#     history = model.fit(
#         train_generator,
#         epochs=epochs,
#         validation_data=validation_generator,
#         validation_steps=validation_steps,  # Specify the correct value here
#         callbacks=[annealer, checkpoint],
#         steps_per_epoch=len(train_generator),
#     )
#     return history


import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score

def modelFit(model, annealer, checkpoint, epochs=20, batchSize=256, validation_steps=32):
    # Assuming you have train_generator and validation_generator defined
    history = model.fit(
        train_generator,
        epochs=epochs,
        validation_data=validation_generator,
        validation_steps=validation_steps,
        callbacks=[annealer, checkpoint],
        steps_per_epoch=len(train_generator),
    )

    # Calculate precision, recall, and F1 score on validation data
    val_predictions = model.predict(validation_generator)
    val_classes = np.argmax(val_predictions, axis=1)  # Assuming multiclass classification
    true_classes = validation_generator.classes

    val_precision = precision_score(true_classes, val_classes, average='macro')
    val_recall = recall_score(true_classes, val_classes, average='macro')
    val_f1score = f1_score(true_classes, val_classes, average='macro')

    print(f"Validation Precision: {val_precision:.4f}")
    print(f"Validation Recall: {val_recall:.4f}")
    print(f"Validation F1 Score: {val_f1score:.4f}")

    return history

# %%
def plotOutput(history, className, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(12, 12))
    plt.subplot(3, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(3, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    plt.savefig(className + '_graph.png')

# %%
def evalModel(model):
    evl = model.evaluate(validation_generator)
    acc = evl[1]*100
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg)
    
def saveModel(model, className):
    model.save(className + " - VGG16.h5")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
def callPlot(model, className, classes):
    y_true = validation_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(validation_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
mpath = r'../input/multi-cancer/Multi Cancer'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 10
lr = 0.001

for i in classPaths:
    print(i)
# Out:
# Cervical Cancer
# Lung and Colon Cancer
# Oral Cancer
# ALL
# Kidney Cancer
# Breast Cancer
# Lymphoma
# Brain Cancer

# %%
className = 'Cervical Cancer '
cpath = os.path.join(mpath, 'Cervical Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 25000 files belonging to 5 classes.
#
# For Training :  Found 17500 images belonging to 5 classes.
#
# For Val :  Found 7500 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['cervix_dyk', 'cervix_koc', 'cervix_mep', 'cervix_pab', 'cervix_sfi']
# Image Shape :  (32, 256, 256, 3)
# 5 ['cervix_dyk', 'cervix_koc', 'cervix_mep', 'cervix_pab', 'cervix_sfi'] <keras.preprocessing.image.DirectoryIterator object at 0x7c0333518290> <keras.preprocessing.image.DirectoryIterator object at 0x7c0332dd02d0>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 125445
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 547/547 [==============================] - 99s 181ms/step - loss: 1.5853 - accuracy: 0.9215 - val_loss: 0.6874 - val_accuracy: 0.9697
#
# Epoch 00001: val_loss improved from inf to 0.68745, saving model to Cervical Cancer VGG16.h5
# Epoch 2/10
# 547/547 [==============================] - 94s 171ms/step - loss: 0.3485 - accuracy: 0.9811 - val_loss: 1.6974 - val_accuracy: 0.9395
#
# Epoch 00002: val_loss did not improve from 0.68745
# Epoch 3/10
# 547/547 [==============================] - 93s 170ms/step - loss: 0.2566 - accuracy: 0.9877 - val_loss: 0.4783 - val_accuracy: 0.9766
#
# Epoch 00003: val_loss improved from 0.68745 to 0.47830, saving model to Cervical Cancer VGG16.h5
# Epoch 4/10
# 547/547 [==============================] - 95s 174ms/step - loss: 0.2433 - accuracy: 0.9898 - val_loss: 2.2850 - val_accuracy: 0.9385
#
# Epoch 00004: val_loss did not improve from 0.47830
# Epoch 5/10
# 547/547 [==============================] - 101s 184ms/step - loss: 0.2324 - accuracy: 0.9920 - val_loss: 0.5383 - val_accuracy: 0.9814
#
# Epoch 00005: val_loss did not improve from 0.47830
# Epoch 6/10
# 547/547 [==============================] - 100s 183ms/step - loss: 0.1359 - accuracy: 0.9946 - val_loss: 2.0457 - val_accuracy: 0.9541
#
# Epoch 00006: val_loss did not improve from 0.47830
# Epoch 7/10
# 547/547 [==============================] - 97s 178ms/step - loss: 0.2547 - accuracy: 0.9920 - val_loss: 0.8398 - val_accuracy: 0.9854
#
# Epoch 00007: val_loss did not improve from 0.47830
# Epoch 8/10
# 547/547 [==============================] - 97s 177ms/step - loss: 0.2715 - accuracy: 0.9926 - val_loss: 0.7045 - val_accuracy: 0.9834
#
# Epoch 00008: val_loss did not improve from 0.47830
# Epoch 9/10
# 547/547 [==============================] - 96s 176ms/step - loss: 0.2073 - accuracy: 0.9947 - val_loss: 0.5375 - val_accuracy: 0.9873
#
# Epoch 00009: val_loss did not improve from 0.47830
# Epoch 10/10
# 547/547 [==============================] - 97s 177ms/step - loss: 0.1787 - accuracy: 0.9949 - val_loss: 1.7275 - val_accuracy: 0.9648
#
# Epoch 00010: val_loss did not improve from 0.47830
# Validation Precision: 0.9875
# Validation Recall: 0.9873
# Validation F1 Score: 0.9873
# 235/235 [==============================] - 38s 161ms/step - loss: 0.6490 - accuracy: 0.9873
# Accuracy on the Test Set = 98.73 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# Predicted :  [0 0 0 ... 4 4 4]

# %%
className = 'Lung and Colon Cancer '
cpath = os.path.join(mpath, 'Lung and Colon Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 25000 files belonging to 5 classes.
#
# For Training :  Found 17500 images belonging to 5 classes.
#
# For Val :  Found 7500 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc']
# Image Shape :  (32, 256, 256, 3)
# 5 ['colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc'] <keras.preprocessing.image.DirectoryIterator object at 0x7c02ab6b6b50> <keras.preprocessing.image.DirectoryIterator object at 0x7c02ab6b6e10>
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 125445
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 547/547 [==============================] - 102s 186ms/step - loss: 1.3333 - accuracy: 0.9394 - val_loss: 0.2611 - val_accuracy: 0.9873
#
# Epoch 00001: val_loss improved from inf to 0.26108, saving model to Lung and Colon Cancer VGG16.h5
# Epoch 2/10
# 547/547 [==============================] - 97s 177ms/step - loss: 0.3989 - accuracy: 0.9818 - val_loss: 0.3302 - val_accuracy: 0.9912
#
# Epoch 00002: val_loss did not improve from 0.26108
# Epoch 3/10
# 547/547 [==============================] - 98s 178ms/step - loss: 0.3764 - accuracy: 0.9861 - val_loss: 0.2907 - val_accuracy: 0.9912
#
# Epoch 00003: val_loss did not improve from 0.26108
# Epoch 4/10
# 547/547 [==============================] - 104s 189ms/step - loss: 0.3460 - accuracy: 0.9882 - val_loss: 2.6804 - val_accuracy: 0.9561
#
# Epoch 00004: val_loss did not improve from 0.26108
# Epoch 5/10
# 547/547 [==============================] - 102s 186ms/step - loss: 0.1786 - accuracy: 0.9933 - val_loss: 0.3475 - val_accuracy: 0.9932
#
# Epoch 00005: val_loss did not improve from 0.26108
# Epoch 6/10
# 547/547 [==============================] - 99s 182ms/step - loss: 0.1081 - accuracy: 0.9959 - val_loss: 0.1348 - val_accuracy: 0.9951
#
# Epoch 00006: val_loss improved from 0.26108 to 0.13476, saving model to Lung and Colon Cancer VGG16.h5
# Epoch 7/10
# 547/547 [==============================] - 99s 181ms/step - loss: 0.2828 - accuracy: 0.9924 - val_loss: 0.9762 - val_accuracy: 0.9814
#
# Epoch 00007: val_loss did not improve from 0.13476
# Epoch 8/10
# 547/547 [==============================] - 98s 178ms/step - loss: 0.2203 - accuracy: 0.9941 - val_loss: 1.7712 - val_accuracy: 0.9727
#
# Epoch 00008: val_loss did not improve from 0.13476
# Epoch 9/10
# 547/547 [==============================] - 98s 178ms/step - loss: 0.2258 - accuracy: 0.9946 - val_loss: 0.0274 - val_accuracy: 0.9990
#
# Epoch 00009: val_loss improved from 0.13476 to 0.02735, saving model to Lung and Colon Cancer VGG16.h5
# Epoch 10/10
# 547/547 [==============================] - 95s 174ms/step - loss: 0.1768 - accuracy: 0.9958 - val_loss: 0.0740 - val_accuracy: 0.9980
#
# Epoch 00010: val_loss did not improve from 0.02735
# Validation Precision: 0.9775
# Validation Recall: 0.9771
# Validation F1 Score: 0.9770
# 235/235 [==============================] - 38s 162ms/step - loss: 1.4803 - accuracy: 0.9771
# Accuracy on the Test Set = 97.71 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# Predicted :  [0 1 0 ... 4 4 4]

# %%
className = 'Oral Cancer '
cpath = os.path.join(mpath, 'Oral Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10002 files belonging to 2 classes.
#
# For Training :  Found 7002 images belonging to 2 classes.
#
# For Val :  Found 3000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['oral_normal', 'oral_scc']
# Image Shape :  (32, 256, 256, 3)
# 2 ['oral_normal', 'oral_scc'] <keras.preprocessing.image.DirectoryIterator object at 0x7c0333518950> <keras.preprocessing.image.DirectoryIterator object at 0x7c0333518bd0>
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 50178
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 219/219 [==============================] - 44s 199ms/step - loss: 6.2651 - accuracy: 0.7436 - val_loss: 3.0057 - val_accuracy: 0.8682
#
# Epoch 00001: val_loss improved from inf to 3.00570, saving model to Oral Cancer VGG16.h5
# Epoch 2/10
# 219/219 [==============================] - 43s 195ms/step - loss: 2.8079 - accuracy: 0.8722 - val_loss: 4.3268 - val_accuracy: 0.8379
#
# Epoch 00002: val_loss did not improve from 3.00570
# Epoch 3/10
# 219/219 [==============================] - 42s 190ms/step - loss: 1.4274 - accuracy: 0.9296 - val_loss: 4.6183 - val_accuracy: 0.8525
#
# Epoch 00003: val_loss did not improve from 3.00570
# Epoch 4/10
# 219/219 [==============================] - 42s 192ms/step - loss: 0.9274 - accuracy: 0.9500 - val_loss: 6.3466 - val_accuracy: 0.8145
#
# Epoch 00004: val_loss did not improve from 3.00570
# Epoch 5/10
# 219/219 [==============================] - 42s 193ms/step - loss: 1.0908 - accuracy: 0.9492 - val_loss: 4.1056 - val_accuracy: 0.8867
#
# Epoch 00005: val_loss did not improve from 3.00570
# Epoch 6/10
# 219/219 [==============================] - 42s 190ms/step - loss: 0.5843 - accuracy: 0.9669 - val_loss: 3.5670 - val_accuracy: 0.8877
#
# Epoch 00006: val_loss did not improve from 3.00570
# Epoch 7/10
# 219/219 [==============================] - 42s 190ms/step - loss: 0.5089 - accuracy: 0.9710 - val_loss: 6.3445 - val_accuracy: 0.8428
#
# Epoch 00007: val_loss did not improve from 3.00570
# Epoch 8/10
# 219/219 [==============================] - 42s 192ms/step - loss: 0.5139 - accuracy: 0.9733 - val_loss: 3.2260 - val_accuracy: 0.9189
#
# Epoch 00008: val_loss did not improve from 3.00570
# Epoch 9/10
# 219/219 [==============================] - 42s 192ms/step - loss: 0.5032 - accuracy: 0.9740 - val_loss: 12.1830 - val_accuracy: 0.7734
#
# Epoch 00009: val_loss did not improve from 3.00570
# Epoch 10/10
# 219/219 [==============================] - 43s 197ms/step - loss: 0.6543 - accuracy: 0.9663 - val_loss: 11.6900 - val_accuracy: 0.7764
#
# Epoch 00010: val_loss did not improve from 3.00570
# Validation Precision: 0.8274
# Validation Recall: 0.8250
# Validation F1 Score: 0.8247
# 94/94 [==============================] - 16s 165ms/step - loss: 8.9030 - accuracy: 0.8250
# Accuracy on the Test Set = 82.50 %
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# Predicted :  [1 0 0 ... 1 1 1]

# %%
className = 'ALL '
cpath = os.path.join(mpath, 'ALL')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 20000 files belonging to 4 classes.
#
# For Training :  Found 14000 images belonging to 4 classes.
#
# For Val :  Found 6000 images belonging to 4 classes.
#
# No of Classes :  4
# Classes :  ['all_benign', 'all_early', 'all_pre', 'all_pro']
# Image Shape :  (32, 256, 256, 3)
# 4 ['all_benign', 'all_early', 'all_pre', 'all_pro'] <keras.preprocessing.image.DirectoryIterator object at 0x7c0332f52550> <keras.preprocessing.image.DirectoryIterator object at 0x7c0332f52490>
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 100356
# =================================================================
# Total params: 14,815,044
# Trainable params: 100,356
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 438/438 [==============================] - 76s 172ms/step - loss: 0.9422 - accuracy: 0.9467 - val_loss: 0.2190 - val_accuracy: 0.9863
#
# Epoch 00001: val_loss improved from inf to 0.21898, saving model to ALL VGG16.h5
# Epoch 2/10
# 438/438 [==============================] - 72s 163ms/step - loss: 0.2259 - accuracy: 0.9876 - val_loss: 0.3349 - val_accuracy: 0.9834
#
# Epoch 00002: val_loss did not improve from 0.21898
# Epoch 3/10
# 438/438 [==============================] - 72s 164ms/step - loss: 0.1708 - accuracy: 0.9926 - val_loss: 0.1191 - val_accuracy: 0.9932
#
# Epoch 00003: val_loss improved from 0.21898 to 0.11906, saving model to ALL VGG16.h5
# Epoch 4/10
# 438/438 [==============================] - 72s 165ms/step - loss: 0.2427 - accuracy: 0.9898 - val_loss: 0.2256 - val_accuracy: 0.9941
#
# Epoch 00004: val_loss did not improve from 0.11906
# Epoch 5/10
# 438/438 [==============================] - 71s 162ms/step - loss: 0.1085 - accuracy: 0.9946 - val_loss: 0.6740 - val_accuracy: 0.9844
#
# Epoch 00005: val_loss did not improve from 0.11906
# Epoch 6/10
# 438/438 [==============================] - 71s 161ms/step - loss: 0.1172 - accuracy: 0.9947 - val_loss: 0.4004 - val_accuracy: 0.9951
#
# Epoch 00006: val_loss did not improve from 0.11906
# Epoch 7/10
# 438/438 [==============================] - 71s 161ms/step - loss: 0.0849 - accuracy: 0.9966 - val_loss: 0.5301 - val_accuracy: 0.9834
#
# Epoch 00007: val_loss did not improve from 0.11906
# Epoch 8/10
# 438/438 [==============================] - 71s 162ms/step - loss: 0.2063 - accuracy: 0.9941 - val_loss: 0.3418 - val_accuracy: 0.9971
#
# Epoch 00008: val_loss did not improve from 0.11906
# Epoch 9/10
# 438/438 [==============================] - 71s 163ms/step - loss: 0.2146 - accuracy: 0.9949 - val_loss: 0.0965 - val_accuracy: 0.9961
#
# Epoch 00009: val_loss improved from 0.11906 to 0.09645, saving model to ALL VGG16.h5
# Epoch 10/10
# 438/438 [==============================] - 71s 161ms/step - loss: 0.1144 - accuracy: 0.9966 - val_loss: 0.7048 - val_accuracy: 0.9834
#
# Epoch 00010: val_loss did not improve from 0.09645
# Validation Precision: 0.9898
# Validation Recall: 0.9897
# Validation F1 Score: 0.9897
# 188/188 [==============================] - 28s 149ms/step - loss: 0.4362 - accuracy: 0.9897
# Accuracy on the Test Set = 98.97 %
# Model Saved!
# True :  [0 0 0 ... 3 3 3]
# Predicted :  [0 0 0 ... 3 3 3]

# %%
className = 'Kidney Cancer '
cpath = os.path.join(mpath, 'Kidney Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10000 files belonging to 2 classes.
#
# For Training :  Found 7000 images belonging to 2 classes.
#
# For Val :  Found 3000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['kidney_normal', 'kidney_tumor']
# Image Shape :  (32, 256, 256, 3)
# 2 ['kidney_normal', 'kidney_tumor'] <keras.preprocessing.image.DirectoryIterator object at 0x7c02aa573fd0> <keras.preprocessing.image.DirectoryIterator object at 0x7c02aa5d3ed0>
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 50178
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 219/219 [==============================] - 40s 179ms/step - loss: 0.6304 - accuracy: 0.9757 - val_loss: 2.5224 - val_accuracy: 0.8633
#
# Epoch 00001: val_loss improved from inf to 2.52244, saving model to Kidney Cancer VGG16.h5
# Epoch 2/10
# 219/219 [==============================] - 37s 170ms/step - loss: 0.0095 - accuracy: 0.9989 - val_loss: 5.6326 - val_accuracy: 0.7842
#
# Epoch 00002: val_loss did not improve from 2.52244
# Epoch 3/10
# 219/219 [==============================] - 37s 170ms/step - loss: 6.8120e-11 - accuracy: 1.0000 - val_loss: 5.6334 - val_accuracy: 0.7842
#
# Epoch 00003: val_loss did not improve from 2.52244
# Epoch 4/10
# 219/219 [==============================] - 37s 168ms/step - loss: 5.1090e-11 - accuracy: 1.0000 - val_loss: 5.6333 - val_accuracy: 0.7842
#
# Epoch 00004: val_loss did not improve from 2.52244
# Epoch 5/10
# 219/219 [==============================] - 37s 170ms/step - loss: 5.1090e-11 - accuracy: 1.0000 - val_loss: 5.6333 - val_accuracy: 0.7842
#
# Epoch 00005: val_loss did not improve from 2.52244
# Epoch 6/10
# 219/219 [==============================] - 37s 169ms/step - loss: 5.1090e-11 - accuracy: 1.0000 - val_loss: 5.6333 - val_accuracy: 0.7842
#
# Epoch 00006: val_loss did not improve from 2.52244
# Epoch 7/10
# 219/219 [==============================] - 37s 168ms/step - loss: 5.1090e-11 - accuracy: 1.0000 - val_loss: 5.6333 - val_accuracy: 0.7842
#
# Epoch 00007: val_loss did not improve from 2.52244
# Epoch 8/10
# 219/219 [==============================] - 37s 170ms/step - loss: 5.1090e-11 - accuracy: 1.0000 - val_loss: 5.6333 - val_accuracy: 0.7842
#
# Epoch 00008: val_loss did not improve from 2.52244
# Epoch 9/10
# 219/219 [==============================] - 37s 170ms/step - loss: 5.1090e-11 - accuracy: 1.0000 - val_loss: 5.6333 - val_accuracy: 0.7842
#
# Epoch 00009: val_loss did not improve from 2.52244
# Epoch 10/10
# 219/219 [==============================] - 37s 168ms/step - loss: 5.1090e-11 - accuracy: 1.0000 - val_loss: 5.6332 - val_accuracy: 0.7842
#
# Epoch 00010: val_loss did not improve from 2.52244
# Validation Precision: 0.8634
# Validation Recall: 0.8137
# Validation F1 Score: 0.8071
# 94/94 [==============================] - 14s 143ms/step - loss: 8.5602 - accuracy: 0.8137
# Accuracy on the Test Set = 81.37 %
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# Predicted :  [0 0 0 ... 1 1 1]

# %%
className = 'Breast Cancer '
cpath = os.path.join(mpath, 'Breast Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10000 files belonging to 2 classes.
#
# For Training :  Found 7000 images belonging to 2 classes.
#
# For Val :  Found 3000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['breast_benign', 'breast_malignant']
# Image Shape :  (32, 256, 256, 3)
# 2 ['breast_benign', 'breast_malignant'] <keras.preprocessing.image.DirectoryIterator object at 0x7c0292009fd0> <keras.preprocessing.image.DirectoryIterator object at 0x7bfe9015a910>
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 50178
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 219/219 [==============================] - 65s 294ms/step - loss: 0.7841 - accuracy: 0.9660 - val_loss: 0.5261 - val_accuracy: 0.9873
#
# Epoch 00001: val_loss improved from inf to 0.52613, saving model to Breast Cancer VGG16.h5
# Epoch 2/10
# 219/219 [==============================] - 63s 286ms/step - loss: 0.3025 - accuracy: 0.9889 - val_loss: 1.9008 - val_accuracy: 0.9678
#
# Epoch 00002: val_loss did not improve from 0.52613
# Epoch 3/10
# 219/219 [==============================] - 65s 294ms/step - loss: 0.1154 - accuracy: 0.9957 - val_loss: 0.6525 - val_accuracy: 0.9863
#
# Epoch 00003: val_loss did not improve from 0.52613
# Epoch 4/10
# 219/219 [==============================] - 64s 292ms/step - loss: 0.1036 - accuracy: 0.9966 - val_loss: 0.9463 - val_accuracy: 0.9844
#
# Epoch 00004: val_loss did not improve from 0.52613
# Epoch 5/10
# 219/219 [==============================] - 63s 286ms/step - loss: 0.0888 - accuracy: 0.9969 - val_loss: 0.3558 - val_accuracy: 0.9932
#
# Epoch 00005: val_loss improved from 0.52613 to 0.35576, saving model to Breast Cancer VGG16.h5
# Epoch 6/10
# 219/219 [==============================] - 63s 286ms/step - loss: 0.0134 - accuracy: 0.9987 - val_loss: 0.8649 - val_accuracy: 0.9854
#
# Epoch 00006: val_loss did not improve from 0.35576
# Epoch 7/10
# 219/219 [==============================] - 62s 284ms/step - loss: 0.0236 - accuracy: 0.9989 - val_loss: 1.3636 - val_accuracy: 0.9785
#
# Epoch 00007: val_loss did not improve from 0.35576
# Epoch 8/10
# 219/219 [==============================] - 62s 285ms/step - loss: 0.0666 - accuracy: 0.9979 - val_loss: 0.2644 - val_accuracy: 0.9951
#
# Epoch 00008: val_loss improved from 0.35576 to 0.26437, saving model to Breast Cancer VGG16.h5
# Epoch 9/10
# 219/219 [==============================] - 63s 287ms/step - loss: 0.1170 - accuracy: 0.9951 - val_loss: 0.3365 - val_accuracy: 0.9922
#
# Epoch 00009: val_loss did not improve from 0.26437
# Epoch 10/10
# 219/219 [==============================] - 63s 290ms/step - loss: 0.0555 - accuracy: 0.9976 - val_loss: 1.4623 - val_accuracy: 0.9844
#
# Epoch 00010: val_loss did not improve from 0.26437
# Validation Precision: 0.9853
# Validation Recall: 0.9853
# Validation F1 Score: 0.9853
# 94/94 [==============================] - 25s 263ms/step - loss: 1.0214 - accuracy: 0.9853
# Accuracy on the Test Set = 98.53 %
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# Predicted :  [0 0 0 ... 1 1 1]

# %%
className = 'Lymphoma '
cpath = os.path.join(mpath, 'Lymphoma')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 15000 files belonging to 3 classes.
#
# For Training :  Found 10500 images belonging to 3 classes.
#
# For Val :  Found 4500 images belonging to 3 classes.
#
# No of Classes :  3
# Classes :  ['lymph_cll', 'lymph_fl', 'lymph_mcl']
# Image Shape :  (32, 256, 256, 3)
# 3 ['lymph_cll', 'lymph_fl', 'lymph_mcl'] <keras.preprocessing.image.DirectoryIterator object at 0x7c0332c51c50> <keras.preprocessing.image.DirectoryIterator object at 0x7c0332c519d0>
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 75267
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 329/329 [==============================] - 70s 210ms/step - loss: 5.2584 - accuracy: 0.6654 - val_loss: 6.4687 - val_accuracy: 0.5518
#
# Epoch 00001: val_loss improved from inf to 6.46866, saving model to Lymphoma VGG16.h5
# Epoch 2/10
# 329/329 [==============================] - 68s 206ms/step - loss: 2.2321 - accuracy: 0.8378 - val_loss: 1.4095 - val_accuracy: 0.9014
#
# Epoch 00002: val_loss improved from 6.46866 to 1.40952, saving model to Lymphoma VGG16.h5
# Epoch 3/10
# 329/329 [==============================] - 68s 205ms/step - loss: 1.4438 - accuracy: 0.8910 - val_loss: 1.3841 - val_accuracy: 0.9023
#
# Epoch 00003: val_loss improved from 1.40952 to 1.38405, saving model to Lymphoma VGG16.h5
# Epoch 4/10
# 329/329 [==============================] - 66s 202ms/step - loss: 1.2157 - accuracy: 0.9104 - val_loss: 2.0148 - val_accuracy: 0.8896
#
# Epoch 00004: val_loss did not improve from 1.38405
# Epoch 5/10
# 329/329 [==============================] - 66s 202ms/step - loss: 1.1095 - accuracy: 0.9206 - val_loss: 4.2130 - val_accuracy: 0.7910
#
# Epoch 00005: val_loss did not improve from 1.38405
# Epoch 6/10
# 329/329 [==============================] - 67s 204ms/step - loss: 0.8779 - accuracy: 0.9347 - val_loss: 2.4217 - val_accuracy: 0.8838
#
# Epoch 00006: val_loss did not improve from 1.38405
# Epoch 7/10
# 329/329 [==============================] - 66s 201ms/step - loss: 0.7789 - accuracy: 0.9418 - val_loss: 1.9005 - val_accuracy: 0.9092
#
# Epoch 00007: val_loss did not improve from 1.38405
# Epoch 8/10
# 329/329 [==============================] - 68s 208ms/step - loss: 0.6315 - accuracy: 0.9528 - val_loss: 1.6598 - val_accuracy: 0.9219
#
# Epoch 00008: val_loss did not improve from 1.38405
# Epoch 9/10
# 329/329 [==============================] - 67s 205ms/step - loss: 0.6076 - accuracy: 0.9573 - val_loss: 8.0580 - val_accuracy: 0.7422
#
# Epoch 00009: val_loss did not improve from 1.38405
# Epoch 10/10
# 329/329 [==============================] - 68s 206ms/step - loss: 0.7116 - accuracy: 0.9559 - val_loss: 4.7484 - val_accuracy: 0.8359
#
# Epoch 00010: val_loss did not improve from 1.38405
# Validation Precision: 0.8548
# Validation Recall: 0.8464
# Validation F1 Score: 0.8457
# 141/141 [==============================] - 27s 190ms/step - loss: 4.2009 - accuracy: 0.8464
# Accuracy on the Test Set = 84.64 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# Predicted :  [0 0 0 ... 2 2 2]

# %%
className = 'Brain Cancer '
cpath = os.path.join(mpath, 'Brain Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 15000 files belonging to 3 classes.
#
# For Training :  Found 10500 images belonging to 3 classes.
#
# For Val :  Found 4500 images belonging to 3 classes.
#
# No of Classes :  3
# Classes :  ['brain_glioma', 'brain_menin', 'brain_tumor']
# Image Shape :  (32, 256, 256, 3)
# 3 ['brain_glioma', 'brain_menin', 'brain_tumor'] <keras.preprocessing.image.DirectoryIterator object at 0x7c02901f0090> <keras.preprocessing.image.DirectoryIterator object at 0x7c02aa5e3190>
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 75267
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
# 329/329 [==============================] - 55s 165ms/step - loss: 2.1659 - accuracy: 0.8932 - val_loss: 1.9439 - val_accuracy: 0.9258
#
# Epoch 00001: val_loss improved from inf to 1.94390, saving model to Brain Cancer VGG16.h5
# Epoch 2/10
# 329/329 [==============================] - 53s 160ms/step - loss: 0.9600 - accuracy: 0.9552 - val_loss: 0.5135 - val_accuracy: 0.9785
#
# Epoch 00002: val_loss improved from 1.94390 to 0.51345, saving model to Brain Cancer VGG16.h5
# Epoch 3/10
# 329/329 [==============================] - 52s 159ms/step - loss: 0.5291 - accuracy: 0.9748 - val_loss: 0.1992 - val_accuracy: 0.9932
#
# Epoch 00003: val_loss improved from 0.51345 to 0.19922, saving model to Brain Cancer VGG16.h5
# Epoch 4/10
# 329/329 [==============================] - 52s 159ms/step - loss: 0.4137 - accuracy: 0.9800 - val_loss: 0.9394 - val_accuracy: 0.9717
#
# Epoch 00004: val_loss did not improve from 0.19922
# Epoch 5/10
# 329/329 [==============================] - 52s 158ms/step - loss: 0.2712 - accuracy: 0.9848 - val_loss: 1.6254 - val_accuracy: 0.9639
#
# Epoch 00005: val_loss did not improve from 0.19922
# Epoch 6/10
# 329/329 [==============================] - 52s 159ms/step - loss: 0.2470 - accuracy: 0.9869 - val_loss: 0.7508 - val_accuracy: 0.9775
#
# Epoch 00006: val_loss did not improve from 0.19922
# Epoch 7/10
# 329/329 [==============================] - 52s 157ms/step - loss: 0.2858 - accuracy: 0.9875 - val_loss: 2.9962 - val_accuracy: 0.9336
#
# Epoch 00007: val_loss did not improve from 0.19922
# Epoch 8/10
# 329/329 [==============================] - 52s 158ms/step - loss: 0.3312 - accuracy: 0.9879 - val_loss: 1.2721 - val_accuracy: 0.9707
#
# Epoch 00008: val_loss did not improve from 0.19922
# Epoch 9/10
# 329/329 [==============================] - 51s 156ms/step - loss: 0.4296 - accuracy: 0.9849 - val_loss: 4.2782 - val_accuracy: 0.9307
#
# Epoch 00009: val_loss did not improve from 0.19922
# Epoch 10/10
# 329/329 [==============================] - 52s 157ms/step - loss: 0.2403 - accuracy: 0.9900 - val_loss: 2.8469 - val_accuracy: 0.9502
#
# Epoch 00010: val_loss did not improve from 0.19922
# Validation Precision: 0.9638
# Validation Recall: 0.9622
# Validation F1 Score: 0.9625
# 141/141 [==============================] - 21s 145ms/step - loss: 1.7789 - accuracy: 0.9622
# Accuracy on the Test Set = 96.22 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# Predicted :  [0 0 0 ... 2 2 2]
